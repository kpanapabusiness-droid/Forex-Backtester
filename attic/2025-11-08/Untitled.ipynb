# %%
# !python scripts/run_from_yaml.py configs/fisher_transform_test.yaml
# Out:
# Running: 'C:\Users\panap\miniconda3\envs\forex_backtester\python.exe' scripts/run_single_debug.py --pair EUR_USD --from 2020-01-01 --to 2024-12-31 --timeframe D --output-dir results/fisher_transform_test
# usage: run_single_debug.py [-h] --pair PAIR --c1 C1 --from START_DATE --to
#                            END_DATE [--timeframe TIMEFRAME]
#                            [--output-dir OUTPUT_DIR] [--baseline BASELINE]
#                            [--exit EXIT] [--debug-decisions]
#                            [--export-indicator]
# run_single_debug.py: error: the following arguments are required: --c1
